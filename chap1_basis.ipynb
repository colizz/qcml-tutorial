# %% [markdown]
# # 第一节 Transformer 基础
#
# 首先观看 3Blue1Brown 对 GPT 可视化的优秀科学短片，理解 GPT 和 Transformer 的基础结构。
#
# 链接：[[bilibili]](), [[YouTube]]()
#
# 请带着问题观看：
#  - GPT 的输入、输出格式是什么？
#  - Token 是什么，在 Transformer 中起到什么作用？
#  - Token 在嵌入（embedding）后的向量维数是多少？Embedding 空间预期有什么性质？
#  - GPT 的温度参数控制的是什么？
